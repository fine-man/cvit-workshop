# %% [markdown]
# <a href="https://colab.research.google.com/github/fine-man/cvit-workshop/blob/main/day1/session2/d1-s2-barcode-detection-scanning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import math
from collections import defaultdict
from matplotlib import pyplot as plt

# %%
# loading the barcode image and converting it into grayscale
original = cv2.imread(f'./input.png')
img = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)

plt.imshow(img, cmap='gray')
plt.show()

# %%
cv2_imshow(cv2.resize(original,None, fx=0.7, fy=0.7, interpolation = cv2.INTER_CUBIC))
# Out:
# <PIL.Image.Image image mode=RGB size=396x107 at 0x7F59DDF7E850>

# %%
img = cv2.resize(img,None,fx=0.7, fy=0.7, interpolation = cv2.INTER_CUBIC)
original = cv2.resize(original,None,fx=0.7, fy=0.7, interpolation = cv2.INTER_CUBIC)
